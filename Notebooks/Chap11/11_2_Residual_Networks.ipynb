# %% [markdown]
# <a href="https://colab.research.google.com/github/ouafi98/Understand-Deep-Learning-Book/blob/main/Notebooks/Chap11/11_2_Residual_Networks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 11.2: Residual Networks**
#
# This notebook adapts the networks for MNIST1D to use residual connections.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-aec2e1u7
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-aec2e1u7
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.11.12)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=5340a9cddc306c1ece2abe46681739b5497042644648be5b47863e715a3246b9
#   Stored in directory: /tmp/pip-ephem-wheel-cache-tqs2t_l_/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# We will adapt this model to have residual connections around the linear layers
# This is the same model we used in practical 8.1, but we can't use the sequential
# class for residual networks (which aren't strictly sequential).  Hence, I've rewritten
# it as a model that inherits from a base class

class ResidualNetwork(torch.nn.Module):
  def __init__(self, input_size, output_size, hidden_size=100, has_residual=True):
    super(ResidualNetwork, self).__init__()
    self.linear1 = nn.Linear(input_size, hidden_size)
    self.linear2 = nn.Linear(hidden_size, hidden_size)
    self.linear3 = nn.Linear(hidden_size, hidden_size)
    self.linear4 = nn.Linear(hidden_size, output_size)
    self.has_residual = has_residual
    print("Initialized MLPBase model with {} parameters".format(self.count_params()))

  def count_params(self):
    return sum([p.view(-1).shape[0] for p in self.parameters()])

# TODO -- Add residual connections to this model
# The order of operations within each block should similar to figure 11.5b
# ie., linear1 first,(ReLU+linear2 in first residual block, ReLU+linear3 in second residual block), linear4 at end
# Replace this function
  def forward(self, x):
    if self.has_residual:
      h1 = self.linear1(x)
      h2 = h1 + self.linear2(nn.ReLU()(h1))
      h3 = h2 + self.linear3(nn.ReLU()(h2))
    else:
      h1 = self.linear1(x).relu()
      h2 = self.linear2(h1).relu()
      h3 = self.linear3(h2).relu()
    return self.linear4(h3)

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
#Define the model
model = ResidualNetwork(40, 10, has_residual=False)

# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# convert data to torch tensors
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long'))
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_val = model(x_val)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initialized MLPBase model with 25310 parameters
# Epoch     0, train loss 1.600352, train error 63.80,  val loss 1.666195, percent error 69.20
# Epoch     1, train loss 1.312253, train error 50.03,  val loss 1.457594, percent error 57.80
# Epoch     2, train loss 1.192658, train error 46.92,  val loss 1.403780, percent error 57.50
# Epoch     3, train loss 0.933456, train error 33.38,  val loss 1.197178, percent error 45.50
# Epoch     4, train loss 0.828683, train error 29.25,  val loss 1.201705, percent error 47.20
# Epoch     5, train loss 0.693134, train error 24.70,  val loss 1.101786, percent error 40.90
# Epoch     6, train loss 0.607160, train error 21.62,  val loss 1.170161, percent error 42.70
# Epoch     7, train loss 0.538724, train error 18.57,  val loss 1.110348, percent error 40.60
# Epoch     8, train loss 0.440754, train error 14.78,  val loss 1.018842, percent error 37.60
# Epoch     9, train loss 0.362717, train error 12.00,  val loss 1.056023, percent error 36.10
# Epoch    10, train loss 0.335125, train error 11.32,  val loss 1.114801, percent error 36.80
# Epoch    11, train loss 0.312911, train error 10.70,  val loss 1.226043, percent error 38.40
# Epoch    12, train loss 0.270543, train error 9.43,  val loss 1.211806, percent error 36.00
# Epoch    13, train loss 0.259702, train error 9.40,  val loss 1.221397, percent error 35.50
# Epoch    14, train loss 0.232390, train error 8.20,  val loss 1.337635, percent error 37.60
# Epoch    15, train loss 0.216659, train error 7.28,  val loss 1.340684, percent error 36.70
# Epoch    16, train loss 0.149063, train error 5.03,  val loss 1.333652, percent error 36.60
# Epoch    17, train loss 0.138722, train error 4.03,  val loss 1.373878, percent error 35.40
# Epoch    18, train loss 0.148859, train error 4.88,  val loss 1.505142, percent error 35.50
# Epoch    19, train loss 0.079743, train error 2.12,  val loss 1.480630, percent error 36.10
# Epoch    20, train loss 0.028387, train error 0.12,  val loss 1.346511, percent error 34.00
# Epoch    21, train loss 0.015254, train error 0.00,  val loss 1.376597, percent error 33.40
# Epoch    22, train loss 0.010775, train error 0.00,  val loss 1.398016, percent error 33.50
# Epoch    23, train loss 0.008885, train error 0.00,  val loss 1.427447, percent error 33.30
# Epoch    24, train loss 0.007620, train error 0.00,  val loss 1.448031, percent error 33.40
# Epoch    25, train loss 0.006759, train error 0.00,  val loss 1.472691, percent error 33.00
# Epoch    26, train loss 0.006136, train error 0.00,  val loss 1.489365, percent error 33.30
# Epoch    27, train loss 0.005593, train error 0.00,  val loss 1.508057, percent error 33.20
# Epoch    28, train loss 0.005149, train error 0.00,  val loss 1.518779, percent error 33.20
# Epoch    29, train loss 0.004807, train error 0.00,  val loss 1.531660, percent error 33.40
# Epoch    30, train loss 0.004477, train error 0.00,  val loss 1.547062, percent error 33.60
# Epoch    31, train loss 0.004166, train error 0.00,  val loss 1.557942, percent error 33.70
# Epoch    32, train loss 0.003936, train error 0.00,  val loss 1.566592, percent error 33.30
# Epoch    33, train loss 0.003731, train error 0.00,  val loss 1.581959, percent error 33.70
# Epoch    34, train loss 0.003524, train error 0.00,  val loss 1.589364, percent error 33.30
# Epoch    35, train loss 0.003354, train error 0.00,  val loss 1.601614, percent error 33.60
# Epoch    36, train loss 0.003216, train error 0.00,  val loss 1.608876, percent error 33.50
# Epoch    37, train loss 0.003052, train error 0.00,  val loss 1.615198, percent error 33.40
# Epoch    38, train loss 0.002918, train error 0.00,  val loss 1.625596, percent error 33.40
# Epoch    39, train loss 0.002801, train error 0.00,  val loss 1.632520, percent error 33.40
# Epoch    40, train loss 0.002739, train error 0.00,  val loss 1.635572, percent error 33.50
# Epoch    41, train loss 0.002685, train error 0.00,  val loss 1.639559, percent error 33.40
# Epoch    42, train loss 0.002635, train error 0.00,  val loss 1.644468, percent error 33.30
# Epoch    43, train loss 0.002585, train error 0.00,  val loss 1.647085, percent error 33.50
# Epoch    44, train loss 0.002538, train error 0.00,  val loss 1.650776, percent error 33.40
# Epoch    45, train loss 0.002493, train error 0.00,  val loss 1.653069, percent error 33.40
# Epoch    46, train loss 0.002449, train error 0.00,  val loss 1.657597, percent error 33.40
# Epoch    47, train loss 0.002407, train error 0.00,  val loss 1.660466, percent error 33.30
# Epoch    48, train loss 0.002366, train error 0.00,  val loss 1.663848, percent error 33.30
# Epoch    49, train loss 0.002326, train error 0.00,  val loss 1.667817, percent error 33.50
# Epoch    50, train loss 0.002288, train error 0.00,  val loss 1.670651, percent error 33.40
# Epoch    51, train loss 0.002251, train error 0.00,  val loss 1.673945, percent error 33.40
# Epoch    52, train loss 0.002215, train error 0.00,  val loss 1.677607, percent error 33.40
# Epoch    53, train loss 0.002181, train error 0.00,  val loss 1.679328, percent error 33.40
# Epoch    54, train loss 0.002147, train error 0.00,  val loss 1.683600, percent error 33.40
# Epoch    55, train loss 0.002114, train error 0.00,  val loss 1.685136, percent error 33.20
# Epoch    56, train loss 0.002082, train error 0.00,  val loss 1.689307, percent error 33.30
# Epoch    57, train loss 0.002051, train error 0.00,  val loss 1.692616, percent error 33.40
# Epoch    58, train loss 0.002021, train error 0.00,  val loss 1.695746, percent error 33.50
# Epoch    59, train loss 0.001992, train error 0.00,  val loss 1.697484, percent error 33.40
# Epoch    60, train loss 0.001977, train error 0.00,  val loss 1.699188, percent error 33.30
# Epoch    61, train loss 0.001963, train error 0.00,  val loss 1.701008, percent error 33.40
# Epoch    62, train loss 0.001949, train error 0.00,  val loss 1.702133, percent error 33.40
# Epoch    63, train loss 0.001935, train error 0.00,  val loss 1.703140, percent error 33.40
# Epoch    64, train loss 0.001922, train error 0.00,  val loss 1.704944, percent error 33.30
# Epoch    65, train loss 0.001909, train error 0.00,  val loss 1.706147, percent error 33.30
# Epoch    66, train loss 0.001895, train error 0.00,  val loss 1.707549, percent error 33.40
# Epoch    67, train loss 0.001883, train error 0.00,  val loss 1.708679, percent error 33.20
# Epoch    68, train loss 0.001870, train error 0.00,  val loss 1.709856, percent error 33.30
# Epoch    69, train loss 0.001857, train error 0.00,  val loss 1.711377, percent error 33.40
# Epoch    70, train loss 0.001845, train error 0.00,  val loss 1.712451, percent error 33.20
# Epoch    71, train loss 0.001833, train error 0.00,  val loss 1.714191, percent error 33.20
# Epoch    72, train loss 0.001821, train error 0.00,  val loss 1.715358, percent error 33.40
# Epoch    73, train loss 0.001809, train error 0.00,  val loss 1.716148, percent error 33.40
# Epoch    74, train loss 0.001797, train error 0.00,  val loss 1.717981, percent error 33.30
# Epoch    75, train loss 0.001785, train error 0.00,  val loss 1.718918, percent error 33.40
# Epoch    76, train loss 0.001774, train error 0.00,  val loss 1.720552, percent error 33.40
# Epoch    77, train loss 0.001763, train error 0.00,  val loss 1.721737, percent error 33.40
# Epoch    78, train loss 0.001751, train error 0.00,  val loss 1.722610, percent error 33.40
# Epoch    79, train loss 0.001740, train error 0.00,  val loss 1.723991, percent error 33.40
# Epoch    80, train loss 0.001735, train error 0.00,  val loss 1.724639, percent error 33.40
# Epoch    81, train loss 0.001729, train error 0.00,  val loss 1.725279, percent error 33.40
# Epoch    82, train loss 0.001724, train error 0.00,  val loss 1.725805, percent error 33.40
# Epoch    83, train loss 0.001718, train error 0.00,  val loss 1.726483, percent error 33.40
# Epoch    84, train loss 0.001713, train error 0.00,  val loss 1.727015, percent error 33.40
# Epoch    85, train loss 0.001708, train error 0.00,  val loss 1.727742, percent error 33.40
# Epoch    86, train loss 0.001702, train error 0.00,  val loss 1.728336, percent error 33.40
# Epoch    87, train loss 0.001697, train error 0.00,  val loss 1.728917, percent error 33.40
# Epoch    88, train loss 0.001692, train error 0.00,  val loss 1.729561, percent error 33.30
# Epoch    89, train loss 0.001687, train error 0.00,  val loss 1.730204, percent error 33.30
# Epoch    90, train loss 0.001682, train error 0.00,  val loss 1.730645, percent error 33.40
# Epoch    91, train loss 0.001676, train error 0.00,  val loss 1.731334, percent error 33.30
# Epoch    92, train loss 0.001671, train error 0.00,  val loss 1.731793, percent error 33.40
# Epoch    93, train loss 0.001666, train error 0.00,  val loss 1.732582, percent error 33.30
# Epoch    94, train loss 0.001661, train error 0.00,  val loss 1.733114, percent error 33.20
# Epoch    95, train loss 0.001656, train error 0.00,  val loss 1.733603, percent error 33.20
# Epoch    96, train loss 0.001651, train error 0.00,  val loss 1.734389, percent error 33.30
# Epoch    97, train loss 0.001646, train error 0.00,  val loss 1.734831, percent error 33.20
# Epoch    98, train loss 0.001641, train error 0.00,  val loss 1.735470, percent error 33.20
# Epoch    99, train loss 0.001637, train error 0.00,  val loss 1.735991, percent error 33.20

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Val Error %3.2f'%(errors_train[-1],errors_val[-1]))
ax.legend()
plt.show()

# %% [markdown]
# The primary motivation of residual networks is to allow training of much deeper networks.
#
# TODO: Try running this network with and without the residual connections.  Does adding the residual connections change the performance?
