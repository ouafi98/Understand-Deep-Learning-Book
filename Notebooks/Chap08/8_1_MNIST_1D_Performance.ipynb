# %% [markdown]
# <a href="https://colab.research.google.com/github/ouafi98/Understand-Deep-Learning-Book/blob/main/Notebooks/Chap08/8_1_MNIST_1D_Performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.1: MNIST_1D_Performance**
#
# This notebook runs a simple neural network on the MNIST1D dataset as in figure 8.2a. It uses code from https://github.com/greydanus/mnist1d to generate the data.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# %pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-p2ug7zt5
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-p2ug7zt5
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.11.12)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=48b6a752c4e243428309d0a0fa439b5b47a9edcc4a2e1310346b2ea4221e4bde
#   Stored in directory: /tmp/pip-ephem-wheel-cache-h1mkedjh/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d

# %% [markdown]
# Let's generate a training and test dataset using the MNIST1D code.  The dataset gets saved as a .pkl file so it doesn't have to be regenerated each time.

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
D_i = 40    # Input dimensions
D_k = 400   # Hidden dimensions
D_o = 10    # Output dimensions
# TODO:
# Define a model with two hidden layers of size 100
# And ReLU activations between them
# Replace this line (see Figure 7.8 of book for help):
model = torch.nn.Sequential(torch.nn.Linear(D_i, D_k),
                            torch.nn.ReLU(),
                            torch.nn.Linear(D_k, D_k),
                            torch.nn.ReLU(),
                            torch.nn.Linear(D_k, D_o));


def weights_init(layer_in):
  # TODO:
  # Initialize the parameters with He initialization
  # Replace this line (see figure 7.8 of book for help)
  print("Initializing layer")
  if isinstance(layer_in, torch.nn.Linear):
    torch.nn.init.kaiming_normal_(layer_in.weight)
    torch.nn.init.zeros_(layer_in.bias)


# Call the function you just defined
model.apply(weights_init)
# Out:
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Sequential(
#   (0): Linear(in_features=40, out_features=400, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=400, out_features=400, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=400, out_features=10, bias=True)
# )

# %%
# choose cross entropy loss function (equation 5.24)
loss_function = torch.nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 10 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.8)
x_train = torch.tensor(data['x'].astype('float32'))
y_train = torch.tensor(data['y'].transpose().astype('int64'))
x_test= torch.tensor(data['x_test'].astype('float32'))
y_test = torch.tensor(data['y_test'].astype('int64'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=32, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 50
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_test = np.zeros((n_epoch))
errors_test = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, batch in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = batch
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_test = model(x_test)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_test_class = torch.max(pred_test.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_test[epoch]= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_test[epoch]= loss_function(pred_test, y_test).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  test loss {losses_test[epoch]:.6f}, test error {errors_test[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Epoch     0, train loss 1.383781, train error 51.03,  test loss 1.505474, test error 57.30
# Epoch     1, train loss 1.040464, train error 38.75,  test loss 1.318364, test error 50.50
# Epoch     2, train loss 0.759448, train error 27.30,  test loss 1.210913, test error 45.70
# Epoch     3, train loss 0.618443, train error 22.57,  test loss 1.154646, test error 41.80
# Epoch     4, train loss 0.511422, train error 18.40,  test loss 1.105310, test error 39.70
# Epoch     5, train loss 0.428555, train error 16.28,  test loss 1.150059, test error 36.70
# Epoch     6, train loss 0.301978, train error 10.97,  test loss 1.129678, test error 34.90
# Epoch     7, train loss 0.207086, train error 7.25,  test loss 1.041606, test error 30.70
# Epoch     8, train loss 0.219885, train error 7.50,  test loss 1.296687, test error 33.30
# Epoch     9, train loss 0.116059, train error 3.80,  test loss 1.156158, test error 30.40
# Epoch    10, train loss 0.183095, train error 6.05,  test loss 1.267234, test error 30.80
# Epoch    11, train loss 0.088424, train error 2.60,  test loss 1.253837, test error 30.90
# Epoch    12, train loss 0.099177, train error 3.35,  test loss 1.236276, test error 31.70
# Epoch    13, train loss 0.124654, train error 4.30,  test loss 1.409208, test error 33.70
# Epoch    14, train loss 0.081156, train error 2.90,  test loss 1.412421, test error 33.30
# Epoch    15, train loss 0.068115, train error 1.95,  test loss 1.375316, test error 32.20
# Epoch    16, train loss 0.133983, train error 4.35,  test loss 1.634017, test error 34.50
# Epoch    17, train loss 0.112511, train error 3.43,  test loss 1.514473, test error 33.50
# Epoch    18, train loss 0.084137, train error 2.88,  test loss 1.476684, test error 33.00
# Epoch    19, train loss 0.072323, train error 2.32,  test loss 1.518509, test error 32.00
# Epoch    20, train loss 0.016443, train error 0.47,  test loss 1.378691, test error 28.40
# Epoch    21, train loss 0.003551, train error 0.03,  test loss 1.227531, test error 27.90
# Epoch    22, train loss 0.001661, train error 0.00,  test loss 1.219962, test error 27.40
# Epoch    23, train loss 0.001181, train error 0.00,  test loss 1.208261, test error 26.50
# Epoch    24, train loss 0.001006, train error 0.00,  test loss 1.209357, test error 26.50
# Epoch    25, train loss 0.000886, train error 0.00,  test loss 1.211906, test error 26.60
# Epoch    26, train loss 0.000798, train error 0.00,  test loss 1.214265, test error 26.30
# Epoch    27, train loss 0.000729, train error 0.00,  test loss 1.216470, test error 26.10
# Epoch    28, train loss 0.000672, train error 0.00,  test loss 1.218620, test error 26.00
# Epoch    29, train loss 0.000624, train error 0.00,  test loss 1.221041, test error 25.90
# Epoch    30, train loss 0.000585, train error 0.00,  test loss 1.224324, test error 25.80
# Epoch    31, train loss 0.000549, train error 0.00,  test loss 1.226782, test error 25.80
# Epoch    32, train loss 0.000519, train error 0.00,  test loss 1.229253, test error 25.70
# Epoch    33, train loss 0.000492, train error 0.00,  test loss 1.231971, test error 25.70
# Epoch    34, train loss 0.000468, train error 0.00,  test loss 1.234224, test error 25.70
# Epoch    35, train loss 0.000447, train error 0.00,  test loss 1.236665, test error 25.70
# Epoch    36, train loss 0.000427, train error 0.00,  test loss 1.239226, test error 25.70
# Epoch    37, train loss 0.000410, train error 0.00,  test loss 1.241561, test error 25.60
# Epoch    38, train loss 0.000394, train error 0.00,  test loss 1.243526, test error 25.60
# Epoch    39, train loss 0.000379, train error 0.00,  test loss 1.245709, test error 25.50
# Epoch    40, train loss 0.000368, train error 0.00,  test loss 1.247770, test error 25.50
# Epoch    41, train loss 0.000358, train error 0.00,  test loss 1.249407, test error 25.40
# Epoch    42, train loss 0.000348, train error 0.00,  test loss 1.250986, test error 25.50
# Epoch    43, train loss 0.000339, train error 0.00,  test loss 1.252683, test error 25.60
# Epoch    44, train loss 0.000331, train error 0.00,  test loss 1.254341, test error 25.60
# Epoch    45, train loss 0.000323, train error 0.00,  test loss 1.256121, test error 25.60
# Epoch    46, train loss 0.000315, train error 0.00,  test loss 1.257458, test error 25.60
# Epoch    47, train loss 0.000308, train error 0.00,  test loss 1.259129, test error 25.50
# Epoch    48, train loss 0.000301, train error 0.00,  test loss 1.260507, test error 25.50
# Epoch    49, train loss 0.000294, train error 0.00,  test loss 1.261959, test error 25.70

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_test,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Test Error %3.2f'%(errors_train[-1],errors_test[-1]))
ax.legend()
plt.show()

# Plot the results
fig, ax = plt.subplots()
ax.plot(losses_train,'r-',label='train')
ax.plot(losses_test,'b-',label='test')
ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
ax.set_title('Train loss %3.2f, Test loss %3.2f'%(losses_train[-1],losses_test[-1]))
ax.legend()
plt.show()

# %% [markdown]
# **TODO**
#
# Play with the model -- try changing the number of layers, hidden units, learning rate, batch size, momentum or anything else you like.  See if you can improve the test results.
#
# Is it a good idea to optimize the hyperparameters in this way?  Will the final result be a good estimate of the true test performance?
