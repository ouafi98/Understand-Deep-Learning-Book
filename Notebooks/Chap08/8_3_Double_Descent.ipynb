# %% [markdown]
# <a href="https://colab.research.google.com/github/ouafi98/Understand-Deep-Learning-Book/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.299135, train error 90.10,  test loss 2.298956, test error 91.03
# Epoch   100, train loss 1.910611, train error 72.90,  test loss 1.757869, test error 69.12
# Epoch   200, train loss 1.904374, train error 71.68,  test loss 1.744357, test error 69.78
# Epoch   300, train loss 1.905829, train error 70.50,  test loss 1.751812, test error 69.05
# Epoch   400, train loss 1.903840, train error 70.50,  test loss 1.743162, test error 69.75
# Epoch   500, train loss 1.902583, train error 70.82,  test loss 1.742885, test error 69.82
# Epoch   600, train loss 1.902591, train error 71.00,  test loss 1.744903, test error 69.60
# Epoch   700, train loss 1.902291, train error 70.88,  test loss 1.741002, test error 70.00
# Epoch   800, train loss 1.902501, train error 70.88,  test loss 1.737914, test error 70.05
# Epoch   900, train loss 1.901978, train error 71.90,  test loss 1.734462, test error 70.07
# Training model with   4 hidden variables
# Epoch     0, train loss 2.284984, train error 87.22,  test loss 2.280119, test error 86.62
# Epoch   100, train loss 1.753172, train error 64.50,  test loss 1.571787, test error 61.65
# Epoch   200, train loss 1.717019, train error 63.20,  test loss 1.526896, test error 59.58
# Epoch   300, train loss 1.700024, train error 62.60,  test loss 1.508957, test error 57.72
# Epoch   400, train loss 1.688627, train error 61.85,  test loss 1.500408, test error 57.83
# Epoch   500, train loss 1.686229, train error 61.38,  test loss 1.503539, test error 57.72
# Epoch   600, train loss 1.684918, train error 62.00,  test loss 1.497827, test error 57.55
# Epoch   700, train loss 1.680965, train error 61.92,  test loss 1.501872, test error 57.83
# Epoch   800, train loss 1.678568, train error 62.47,  test loss 1.500397, test error 58.12
# Epoch   900, train loss 1.680134, train error 61.40,  test loss 1.497647, test error 58.47
# Training model with   6 hidden variables
# Epoch     0, train loss 2.300532, train error 88.53,  test loss 2.306213, test error 88.75
# Epoch   100, train loss 1.672964, train error 60.38,  test loss 1.503113, test error 57.55
# Epoch   200, train loss 1.607499, train error 56.25,  test loss 1.417823, test error 53.83
# Epoch   300, train loss 1.585776, train error 55.72,  test loss 1.403188, test error 52.95
# Epoch   400, train loss 1.574805, train error 54.72,  test loss 1.396981, test error 52.90
# Epoch   500, train loss 1.556897, train error 54.67,  test loss 1.380804, test error 52.47
# Epoch   600, train loss 1.549188, train error 54.62,  test loss 1.379439, test error 52.38
# Epoch   700, train loss 1.547470, train error 54.33,  test loss 1.377758, test error 52.08
# Epoch   800, train loss 1.543868, train error 54.10,  test loss 1.378218, test error 52.38
# Epoch   900, train loss 1.539279, train error 53.92,  test loss 1.383014, test error 51.58
# Training model with   8 hidden variables
# Epoch     0, train loss 2.227844, train error 83.60,  test loss 2.212606, test error 84.93
# Epoch   100, train loss 1.622768, train error 58.60,  test loss 1.488715, test error 58.08
# Epoch   200, train loss 1.576841, train error 57.10,  test loss 1.452942, test error 56.40
# Epoch   300, train loss 1.556961, train error 55.95,  test loss 1.448804, test error 56.35
# Epoch   400, train loss 1.553531, train error 55.05,  test loss 1.452107, test error 55.60
# Epoch   500, train loss 1.540683, train error 55.45,  test loss 1.461808, test error 56.25
# Epoch   600, train loss 1.540703, train error 56.38,  test loss 1.454371, test error 55.53
# Epoch   700, train loss 1.533239, train error 55.20,  test loss 1.463650, test error 55.67
# Epoch   800, train loss 1.528538, train error 55.50,  test loss 1.464283, test error 56.75
# Epoch   900, train loss 1.528621, train error 54.95,  test loss 1.466338, test error 54.97
# Training model with  10 hidden variables
# Epoch     0, train loss 2.278023, train error 85.30,  test loss 2.274681, test error 85.38
# Epoch   100, train loss 1.522557, train error 53.53,  test loss 1.374905, test error 52.67
# Epoch   200, train loss 1.423306, train error 48.03,  test loss 1.283844, test error 47.47
# Epoch   300, train loss 1.412092, train error 48.35,  test loss 1.286073, test error 47.78
# Epoch   400, train loss 1.400360, train error 47.85,  test loss 1.301429, test error 48.47
# Epoch   500, train loss 1.397958, train error 47.35,  test loss 1.298928, test error 47.62
# Epoch   600, train loss 1.389828, train error 47.35,  test loss 1.299892, test error 47.72
# Epoch   700, train loss 1.388188, train error 47.35,  test loss 1.310693, test error 47.72
# Epoch   800, train loss 1.390204, train error 46.55,  test loss 1.318807, test error 48.12
# Epoch   900, train loss 1.386155, train error 47.47,  test loss 1.322615, test error 49.35
# Training model with  14 hidden variables
# Epoch     0, train loss 2.272422, train error 87.57,  test loss 2.264959, test error 87.07
# Epoch   100, train loss 1.395802, train error 46.15,  test loss 1.279721, test error 47.10
# Epoch   200, train loss 1.330379, train error 44.08,  test loss 1.279298, test error 47.17
# Epoch   300, train loss 1.301601, train error 42.95,  test loss 1.303417, test error 47.53
# Epoch   400, train loss 1.296571, train error 43.15,  test loss 1.324169, test error 47.65
# Epoch   500, train loss 1.281173, train error 42.35,  test loss 1.337019, test error 47.83
# Epoch   600, train loss 1.272192, train error 42.12,  test loss 1.361180, test error 48.30
# Epoch   700, train loss 1.261051, train error 42.08,  test loss 1.375506, test error 48.60
# Epoch   800, train loss 1.259670, train error 42.33,  test loss 1.391226, test error 49.45
# Epoch   900, train loss 1.248480, train error 42.33,  test loss 1.390715, test error 48.80
# Training model with  18 hidden variables
# Epoch     0, train loss 2.273739, train error 85.55,  test loss 2.271257, test error 85.10
# Epoch   100, train loss 1.333441, train error 44.67,  test loss 1.325121, test error 50.12
# Epoch   200, train loss 1.225645, train error 41.45,  test loss 1.332501, test error 49.12
# Epoch   300, train loss 1.189306, train error 40.33,  test loss 1.365254, test error 48.72
# Epoch   400, train loss 1.160021, train error 39.10,  test loss 1.395644, test error 49.72
# Epoch   500, train loss 1.145901, train error 39.28,  test loss 1.416984, test error 50.17
# Epoch   600, train loss 1.138856, train error 38.90,  test loss 1.448849, test error 50.35
# Epoch   700, train loss 1.132089, train error 39.95,  test loss 1.469320, test error 51.22
# Epoch   800, train loss 1.131378, train error 39.05,  test loss 1.478293, test error 50.85
# Epoch   900, train loss 1.122260, train error 39.22,  test loss 1.509764, test error 51.58
# Training model with  22 hidden variables
# Epoch     0, train loss 2.188057, train error 81.12,  test loss 2.156536, test error 80.10
# Epoch   100, train loss 1.254826, train error 41.28,  test loss 1.301489, test error 49.10
# Epoch   200, train loss 1.132182, train error 37.22,  test loss 1.328116, test error 48.85
# Epoch   300, train loss 1.084938, train error 36.40,  test loss 1.399790, test error 49.80
# Epoch   400, train loss 1.043113, train error 35.72,  test loss 1.461330, test error 50.42
# Epoch   500, train loss 1.021108, train error 35.18,  test loss 1.537127, test error 50.97
# Epoch   600, train loss 1.007540, train error 35.00,  test loss 1.602395, test error 52.28
# Epoch   700, train loss 0.987662, train error 34.50,  test loss 1.637779, test error 52.12
# Epoch   800, train loss 0.974049, train error 33.78,  test loss 1.689243, test error 52.83
# Epoch   900, train loss 0.961147, train error 33.25,  test loss 1.703166, test error 51.60
# Training model with  26 hidden variables
# Epoch     0, train loss 2.136434, train error 79.22,  test loss 2.089831, test error 78.90
# Epoch   100, train loss 1.191566, train error 39.17,  test loss 1.269477, test error 46.88
# Epoch   200, train loss 1.031400, train error 34.20,  test loss 1.350341, test error 48.00
# Epoch   300, train loss 0.971971, train error 32.35,  test loss 1.498851, test error 49.50
# Epoch   400, train loss 0.915067, train error 30.35,  test loss 1.626737, test error 50.55
# Epoch   500, train loss 0.891101, train error 29.97,  test loss 1.732571, test error 51.90
# Epoch   600, train loss 0.864478, train error 28.35,  test loss 1.779861, test error 51.33
# Epoch   700, train loss 0.840587, train error 27.62,  test loss 1.805559, test error 51.17
# Epoch   800, train loss 0.835334, train error 27.30,  test loss 1.888964, test error 52.00
# Epoch   900, train loss 0.821715, train error 28.03,  test loss 1.954473, test error 51.50
# Training model with  30 hidden variables
# Epoch     0, train loss 2.174060, train error 80.15,  test loss 2.149497, test error 79.07
# Epoch   100, train loss 1.103331, train error 36.35,  test loss 1.374069, test error 49.75
# Epoch   200, train loss 0.905242, train error 30.12,  test loss 1.585468, test error 51.05
# Epoch   300, train loss 0.823725, train error 28.07,  test loss 1.802686, test error 51.55
# Epoch   400, train loss 0.761887, train error 26.12,  test loss 2.003285, test error 52.80
# Epoch   500, train loss 0.717389, train error 24.60,  test loss 2.244943, test error 54.88
# Epoch   600, train loss 0.691011, train error 23.57,  test loss 2.472347, test error 54.92
# Epoch   700, train loss 0.672499, train error 23.35,  test loss 2.606333, test error 54.60
# Epoch   800, train loss 0.666588, train error 23.43,  test loss 2.777292, test error 54.95
# Epoch   900, train loss 0.658440, train error 22.97,  test loss 2.948970, test error 55.47
# Training model with  35 hidden variables
# Epoch     0, train loss 2.113837, train error 78.18,  test loss 2.088752, test error 78.70
# Epoch   100, train loss 0.980811, train error 31.78,  test loss 1.356309, test error 47.97
# Epoch   200, train loss 0.726688, train error 23.97,  test loss 1.723500, test error 49.85
# Epoch   300, train loss 0.624346, train error 21.05,  test loss 2.167534, test error 52.35
# Epoch   400, train loss 0.555745, train error 18.38,  test loss 2.498991, test error 52.92
# Epoch   500, train loss 0.561009, train error 19.32,  test loss 2.916177, test error 53.75
# Epoch   600, train loss 0.523986, train error 18.15,  test loss 3.200992, test error 54.03
# Epoch   700, train loss 0.448356, train error 15.70,  test loss 3.587988, test error 54.33
# Epoch   800, train loss 0.447374, train error 15.72,  test loss 3.930808, test error 54.62
# Epoch   900, train loss 0.446561, train error 15.97,  test loss 4.203998, test error 55.10
# Training model with  40 hidden variables
# Epoch     0, train loss 2.180626, train error 79.45,  test loss 2.156600, test error 79.32
# Epoch   100, train loss 0.924465, train error 29.68,  test loss 1.408432, test error 49.60
# Epoch   200, train loss 0.633361, train error 20.80,  test loss 1.920812, test error 52.00
# Epoch   300, train loss 0.467106, train error 15.40,  test loss 2.583376, test error 53.10
# Epoch   400, train loss 0.426011, train error 14.10,  test loss 3.251918, test error 52.90
# Epoch   500, train loss 0.353566, train error 11.85,  test loss 3.982878, test error 54.65
# Epoch   600, train loss 0.347900, train error 12.55,  test loss 4.670410, test error 54.90
# Epoch   700, train loss 0.277034, train error 9.05,  test loss 5.307008, test error 54.17
# Epoch   800, train loss 0.278981, train error 9.57,  test loss 5.973520, test error 56.05
# Epoch   900, train loss 0.214230, train error 7.80,  test loss 6.607409, test error 56.10
# Training model with  45 hidden variables
# Epoch     0, train loss 2.120126, train error 78.57,  test loss 2.077755, test error 77.30
# Epoch   100, train loss 0.855728, train error 27.05,  test loss 1.587343, test error 52.88
# Epoch   200, train loss 0.501523, train error 16.53,  test loss 2.355890, test error 53.42
# Epoch   300, train loss 0.328727, train error 11.22,  test loss 3.481928, test error 54.78
# Epoch   400, train loss 0.297508, train error 11.03,  test loss 4.712004, test error 55.80
# Epoch   500, train loss 0.195260, train error 6.68,  test loss 6.041173, test error 55.97
# Epoch   600, train loss 0.201168, train error 6.82,  test loss 7.386397, test error 56.67
# Epoch   700, train loss 0.019823, train error 0.05,  test loss 8.593594, test error 56.58
# Epoch   800, train loss 0.012009, train error 0.00,  test loss 9.522251, test error 56.80
# Epoch   900, train loss 0.008674, train error 0.00,  test loss 10.213162, test error 56.67
# Training model with  50 hidden variables
# Epoch     0, train loss 2.063885, train error 76.70,  test loss 2.011081, test error 77.47
# Epoch   100, train loss 0.690982, train error 21.43,  test loss 1.547799, test error 48.85
# Epoch   200, train loss 0.328376, train error 9.70,  test loss 2.585807, test error 53.10
# Epoch   300, train loss 0.150844, train error 4.03,  test loss 4.110103, test error 54.75
# Epoch   400, train loss 0.028930, train error 0.00,  test loss 5.525892, test error 55.47
# Epoch   500, train loss 0.013427, train error 0.00,  test loss 6.466402, test error 55.95
# Epoch   600, train loss 0.008515, train error 0.00,  test loss 7.080301, test error 56.12
# Epoch   700, train loss 0.006056, train error 0.00,  test loss 7.534320, test error 56.00
# Epoch   800, train loss 0.004671, train error 0.00,  test loss 7.893070, test error 56.12
# Epoch   900, train loss 0.003744, train error 0.00,  test loss 8.195835, test error 56.12
# Training model with  55 hidden variables
# Epoch     0, train loss 2.089698, train error 77.47,  test loss 2.047616, test error 76.80
# Epoch   100, train loss 0.655737, train error 19.82,  test loss 1.660807, test error 52.53
# Epoch   200, train loss 0.251046, train error 6.00,  test loss 2.856908, test error 54.90
# Epoch   300, train loss 0.065521, train error 0.35,  test loss 4.459676, test error 55.22
# Epoch   400, train loss 0.017241, train error 0.00,  test loss 5.612063, test error 55.17
# Epoch   500, train loss 0.009423, train error 0.00,  test loss 6.284230, test error 55.20
# Epoch   600, train loss 0.006351, train error 0.00,  test loss 6.764349, test error 54.97
# Epoch   700, train loss 0.004694, train error 0.00,  test loss 7.131685, test error 54.85
# Epoch   800, train loss 0.003667, train error 0.00,  test loss 7.428208, test error 54.62
# Epoch   900, train loss 0.002995, train error 0.00,  test loss 7.674773, test error 54.80
# Training model with  60 hidden variables
# Epoch     0, train loss 2.079060, train error 77.35,  test loss 2.056041, test error 77.25
# Epoch   100, train loss 0.523142, train error 15.18,  test loss 1.801722, test error 52.40
# Epoch   200, train loss 0.117178, train error 1.78,  test loss 3.504300, test error 54.55
# Epoch   300, train loss 0.019655, train error 0.00,  test loss 4.861941, test error 55.33
# Epoch   400, train loss 0.009583, train error 0.00,  test loss 5.549349, test error 55.42
# Epoch   500, train loss 0.006053, train error 0.00,  test loss 6.011118, test error 55.58
# Epoch   600, train loss 0.004344, train error 0.00,  test loss 6.355018, test error 55.78
# Epoch   700, train loss 0.003333, train error 0.00,  test loss 6.622848, test error 55.65
# Epoch   800, train loss 0.002681, train error 0.00,  test loss 6.849173, test error 55.80
# Epoch   900, train loss 0.002226, train error 0.00,  test loss 7.040228, test error 55.75
# Training model with  70 hidden variables
# Epoch     0, train loss 2.023960, train error 75.03,  test loss 1.977895, test error 74.80
# Epoch   100, train loss 0.347143, train error 9.18,  test loss 2.037007, test error 51.67
# Epoch   200, train loss 0.031595, train error 0.00,  test loss 3.770473, test error 53.55
# Epoch   300, train loss 0.010831, train error 0.00,  test loss 4.610450, test error 53.92
# Epoch   400, train loss 0.006091, train error 0.00,  test loss 5.082965, test error 54.08
# Epoch   500, train loss 0.004098, train error 0.00,  test loss 5.410165, test error 54.25
# Epoch   600, train loss 0.003042, train error 0.00,  test loss 5.666362, test error 54.15
# Epoch   700, train loss 0.002391, train error 0.00,  test loss 5.868514, test error 54.25
# Epoch   800, train loss 0.001952, train error 0.00,  test loss 6.043256, test error 54.22
# Epoch   900, train loss 0.001643, train error 0.00,  test loss 6.189227, test error 54.35
# Training model with  80 hidden variables
# Epoch     0, train loss 2.023050, train error 75.45,  test loss 1.977771, test error 76.12
# Epoch   100, train loss 0.210589, train error 3.40,  test loss 2.103897, test error 51.30
# Epoch   200, train loss 0.018940, train error 0.00,  test loss 3.397092, test error 52.72
# Epoch   300, train loss 0.007634, train error 0.00,  test loss 3.917708, test error 52.65
# Epoch   400, train loss 0.004555, train error 0.00,  test loss 4.236372, test error 52.70
# Epoch   500, train loss 0.003162, train error 0.00,  test loss 4.460149, test error 52.78
# Epoch   600, train loss 0.002389, train error 0.00,  test loss 4.637336, test error 52.60
# Epoch   700, train loss 0.001903, train error 0.00,  test loss 4.778383, test error 52.47
# Epoch   800, train loss 0.001570, train error 0.00,  test loss 4.901657, test error 52.67
# Epoch   900, train loss 0.001329, train error 0.00,  test loss 5.006173, test error 52.65
# Training model with  90 hidden variables
# Epoch     0, train loss 1.979954, train error 74.30,  test loss 1.907885, test error 72.80
# Epoch   100, train loss 0.137557, train error 1.05,  test loss 2.243613, test error 52.15
# Epoch   200, train loss 0.014611, train error 0.00,  test loss 3.376129, test error 53.22
# Epoch   300, train loss 0.006492, train error 0.00,  test loss 3.833441, test error 53.20
# Epoch   400, train loss 0.003986, train error 0.00,  test loss 4.110122, test error 53.05
# Epoch   500, train loss 0.002797, train error 0.00,  test loss 4.309593, test error 53.17
# Epoch   600, train loss 0.002130, train error 0.00,  test loss 4.466355, test error 53.17
# Epoch   700, train loss 0.001705, train error 0.00,  test loss 4.594404, test error 53.08
# Epoch   800, train loss 0.001412, train error 0.00,  test loss 4.702255, test error 53.25
# Epoch   900, train loss 0.001200, train error 0.00,  test loss 4.796001, test error 53.38
# Training model with 100 hidden variables
# Epoch     0, train loss 1.995142, train error 73.05,  test loss 1.925689, test error 73.18
# Epoch   100, train loss 0.090609, train error 0.07,  test loss 2.222922, test error 50.60
# Epoch   200, train loss 0.012070, train error 0.00,  test loss 3.069206, test error 50.97
# Epoch   300, train loss 0.005604, train error 0.00,  test loss 3.431946, test error 50.90
# Epoch   400, train loss 0.003512, train error 0.00,  test loss 3.655245, test error 51.00
# Epoch   500, train loss 0.002497, train error 0.00,  test loss 3.819867, test error 51.10
# Epoch   600, train loss 0.001913, train error 0.00,  test loss 3.947916, test error 51.00
# Epoch   700, train loss 0.001538, train error 0.00,  test loss 4.054115, test error 51.15
# Epoch   800, train loss 0.001278, train error 0.00,  test loss 4.143309, test error 51.22
# Epoch   900, train loss 0.001089, train error 0.00,  test loss 4.221772, test error 51.35
# Training model with 120 hidden variables
# Epoch     0, train loss 1.965488, train error 72.62,  test loss 1.898360, test error 73.85
# Epoch   100, train loss 0.054183, train error 0.03,  test loss 2.195545, test error 49.58
# Epoch   200, train loss 0.009580, train error 0.00,  test loss 2.804760, test error 49.60
# Epoch   300, train loss 0.004715, train error 0.00,  test loss 3.081729, test error 49.65
# Epoch   400, train loss 0.003020, train error 0.00,  test loss 3.260475, test error 49.70
# Epoch   500, train loss 0.002169, train error 0.00,  test loss 3.390971, test error 49.67
# Epoch   600, train loss 0.001676, train error 0.00,  test loss 3.495816, test error 49.67
# Epoch   700, train loss 0.001356, train error 0.00,  test loss 3.581758, test error 49.75
# Epoch   800, train loss 0.001131, train error 0.00,  test loss 3.654466, test error 49.70
# Epoch   900, train loss 0.000967, train error 0.00,  test loss 3.718348, test error 49.78
# Training model with 140 hidden variables
# Epoch     0, train loss 1.952893, train error 71.70,  test loss 1.895689, test error 72.62
# Epoch   100, train loss 0.037066, train error 0.00,  test loss 2.214831, test error 50.15
# Epoch   200, train loss 0.008193, train error 0.00,  test loss 2.726305, test error 49.95
# Epoch   300, train loss 0.004195, train error 0.00,  test loss 2.965660, test error 50.12
# Epoch   400, train loss 0.002721, train error 0.00,  test loss 3.121006, test error 50.00
# Epoch   500, train loss 0.001977, train error 0.00,  test loss 3.238949, test error 50.05
# Epoch   600, train loss 0.001537, train error 0.00,  test loss 3.331721, test error 50.15
# Epoch   700, train loss 0.001247, train error 0.00,  test loss 3.408272, test error 50.12
# Epoch   800, train loss 0.001045, train error 0.00,  test loss 3.474205, test error 50.08
# Epoch   900, train loss 0.000895, train error 0.00,  test loss 3.531211, test error 49.97
# Training model with 160 hidden variables
# Epoch     0, train loss 1.932678, train error 71.65,  test loss 1.842420, test error 73.10
# Epoch   100, train loss 0.027965, train error 0.00,  test loss 2.058981, test error 47.88
# Epoch   200, train loss 0.007145, train error 0.00,  test loss 2.445347, test error 48.17
# Epoch   300, train loss 0.003754, train error 0.00,  test loss 2.636245, test error 48.20
# Epoch   400, train loss 0.002464, train error 0.00,  test loss 2.763147, test error 48.67
# Epoch   500, train loss 0.001804, train error 0.00,  test loss 2.858388, test error 48.80
# Epoch   600, train loss 0.001409, train error 0.00,  test loss 2.934033, test error 48.65
# Epoch   700, train loss 0.001148, train error 0.00,  test loss 2.997492, test error 48.72
# Epoch   800, train loss 0.000964, train error 0.00,  test loss 3.051668, test error 48.70
# Epoch   900, train loss 0.000827, train error 0.00,  test loss 3.098068, test error 48.67
# Training model with 180 hidden variables
# Epoch     0, train loss 1.931892, train error 71.93,  test loss 1.859910, test error 71.72
# Epoch   100, train loss 0.025260, train error 0.00,  test loss 2.064870, test error 48.90
# Epoch   200, train loss 0.006747, train error 0.00,  test loss 2.429004, test error 48.62
# Epoch   300, train loss 0.003606, train error 0.00,  test loss 2.612919, test error 48.55
# Epoch   400, train loss 0.002386, train error 0.00,  test loss 2.735842, test error 48.62
# Epoch   500, train loss 0.001756, train error 0.00,  test loss 2.827997, test error 48.62
# Epoch   600, train loss 0.001375, train error 0.00,  test loss 2.902206, test error 48.42
# Epoch   700, train loss 0.001122, train error 0.00,  test loss 2.963573, test error 48.58
# Epoch   800, train loss 0.000944, train error 0.00,  test loss 3.016557, test error 48.45
# Epoch   900, train loss 0.000811, train error 0.00,  test loss 3.062494, test error 48.50
# Training model with 200 hidden variables
# Epoch     0, train loss 1.931786, train error 71.75,  test loss 1.878720, test error 72.57
# Epoch   100, train loss 0.021523, train error 0.00,  test loss 1.956888, test error 47.70
# Epoch   200, train loss 0.006189, train error 0.00,  test loss 2.267684, test error 47.20
# Epoch   300, train loss 0.003361, train error 0.00,  test loss 2.429228, test error 47.33
# Epoch   400, train loss 0.002243, train error 0.00,  test loss 2.536828, test error 47.28
# Epoch   500, train loss 0.001656, train error 0.00,  test loss 2.618678, test error 47.20
# Epoch   600, train loss 0.001301, train error 0.00,  test loss 2.684170, test error 47.25
# Epoch   700, train loss 0.001064, train error 0.00,  test loss 2.738945, test error 47.25
# Epoch   800, train loss 0.000896, train error 0.00,  test loss 2.785766, test error 47.33
# Epoch   900, train loss 0.000771, train error 0.00,  test loss 2.827254, test error 47.38
# Training model with 250 hidden variables
# Epoch     0, train loss 1.937053, train error 71.95,  test loss 1.883939, test error 73.68
# Epoch   100, train loss 0.017333, train error 0.00,  test loss 1.914806, test error 47.05
# Epoch   200, train loss 0.005411, train error 0.00,  test loss 2.171704, test error 47.20
# Epoch   300, train loss 0.003006, train error 0.00,  test loss 2.304449, test error 47.33
# Epoch   400, train loss 0.002028, train error 0.00,  test loss 2.395155, test error 47.08
# Epoch   500, train loss 0.001508, train error 0.00,  test loss 2.464128, test error 47.08
# Epoch   600, train loss 0.001190, train error 0.00,  test loss 2.519976, test error 47.03
# Epoch   700, train loss 0.000976, train error 0.00,  test loss 2.565879, test error 47.03
# Epoch   800, train loss 0.000824, train error 0.00,  test loss 2.606696, test error 47.08
# Epoch   900, train loss 0.000711, train error 0.00,  test loss 2.641696, test error 46.97
# Training model with 300 hidden variables
# Epoch     0, train loss 1.872360, train error 67.43,  test loss 1.796360, test error 70.25
# Epoch   100, train loss 0.014533, train error 0.00,  test loss 1.804919, test error 46.83
# Epoch   200, train loss 0.004827, train error 0.00,  test loss 2.010647, test error 46.38
# Epoch   300, train loss 0.002739, train error 0.00,  test loss 2.124707, test error 46.10
# Epoch   400, train loss 0.001864, train error 0.00,  test loss 2.203222, test error 46.00
# Epoch   500, train loss 0.001395, train error 0.00,  test loss 2.262185, test error 46.12
# Epoch   600, train loss 0.001105, train error 0.00,  test loss 2.310927, test error 46.12
# Epoch   700, train loss 0.000910, train error 0.00,  test loss 2.351307, test error 46.20
# Epoch   800, train loss 0.000770, train error 0.00,  test loss 2.386347, test error 46.15
# Epoch   900, train loss 0.000665, train error 0.00,  test loss 2.417144, test error 46.17
# Training model with 400 hidden variables
# Epoch     0, train loss 1.853709, train error 66.50,  test loss 1.781331, test error 69.62
# Epoch   100, train loss 0.011645, train error 0.00,  test loss 1.755584, test error 46.17
# Epoch   200, train loss 0.004132, train error 0.00,  test loss 1.931120, test error 46.00
# Epoch   300, train loss 0.002397, train error 0.00,  test loss 2.030010, test error 45.90
# Epoch   400, train loss 0.001651, train error 0.00,  test loss 2.098791, test error 45.85
# Epoch   500, train loss 0.001244, train error 0.00,  test loss 2.150813, test error 45.67
# Epoch   600, train loss 0.000991, train error 0.00,  test loss 2.194084, test error 45.62
# Epoch   700, train loss 0.000819, train error 0.00,  test loss 2.230134, test error 45.60
# Epoch   800, train loss 0.000695, train error 0.00,  test loss 2.261494, test error 45.55
# Epoch   900, train loss 0.000602, train error 0.00,  test loss 2.288870, test error 45.53

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
