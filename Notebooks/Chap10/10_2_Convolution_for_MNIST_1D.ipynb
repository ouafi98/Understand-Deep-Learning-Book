# %% [markdown]
# <a href="https://colab.research.google.com/github/ouafi98/Understand-Deep-Learning-Book/blob/main/Notebooks/Chap10/10_2_Convolution_for_MNIST_1D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 10.2: Convolution for MNIST-1D**
#
# This notebook investigates a 1D convolutional network for MNIST-1D as in figure 10.7 and 10.8a.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-5593b4l8
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-5593b4l8
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.11.12)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=77876e83ae063a49ec0d0e975f142e458ccc4eae64d7c0927b601bbd838abaec
#   Stored in directory: /tmp/pip-ephem-wheel-cache-21lfwr47/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# TODO Create a model with the following layers
# 1. Convolutional layer, (input=length 40 and 1 channel, kernel size 3, stride 2, padding="valid", 15 output channels )
# 2. ReLU
# 3. Convolutional layer, (input=length 19 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels )
# 4. ReLU
# 5. Convolutional layer, (input=length 9 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels)
# 6. ReLU
# 7. Flatten (converts 4x15) to length 60
# 8. Linear layer (input size = 60, output size = 10)
# References:
# https://pytorch.org/docs/1.13/generated/torch.nn.Conv1d.html?highlight=conv1d#torch.nn.Conv1d
# https://pytorch.org/docs/stable/generated/torch.nn.Flatten.html
# https://pytorch.org/docs/1.13/generated/torch.nn.Linear.html?highlight=linear#torch.nn.Linear

# NOTE THAT THE CONVOLUTIONAL LAYERS NEED TO TAKE THE NUMBER OF INPUT CHANNELS AS A PARAMETER
# AND NOT THE INPUT SIZE.

# Replace the following function:
model = nn.Sequential(nn.Conv1d(1, 15, 3, 2, "valid"),
                      nn.ReLU(),
                      nn.Conv1d(15, 15, 3, 2, "valid"),
                      nn.ReLU(),
                      nn.Conv1d(15, 15, 3, 2, "valid"),
                      nn.ReLU(),
                      nn.Flatten(),
                      nn.Linear(60, 10)
                      )

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.9)
# create 100 dummy data points and store in data loader class
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long')).long()
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long')).long()

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch[:,None,:])
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()
  scheduler.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train[:,None,:])
  pred_val = model(x_val[:,None,:])
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()

# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='validation')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('Part I: Validation Result %3.2f'%(errors_val[-1]))
ax.legend()
plt.show()
# Out:
# Epoch     0, train loss 1.100580, train error 39.97,  val loss 1.112742, percent error 40.40
# Epoch     1, train loss 0.647331, train error 23.53,  val loss 0.662358, percent error 25.50
# Epoch     2, train loss 0.431114, train error 14.70,  val loss 0.494531, percent error 17.60
# Epoch     3, train loss 0.443489, train error 16.20,  val loss 0.535306, percent error 17.90
# Epoch     4, train loss 0.363697, train error 12.70,  val loss 0.470837, percent error 16.10
# Epoch     5, train loss 0.288926, train error 10.12,  val loss 0.382008, percent error 12.50
# Epoch     6, train loss 0.312813, train error 11.07,  val loss 0.431485, percent error 14.00
# Epoch     7, train loss 0.246851, train error 8.72,  val loss 0.385010, percent error 12.40
# Epoch     8, train loss 0.220359, train error 7.90,  val loss 0.366688, percent error 11.10
# Epoch     9, train loss 0.400994, train error 13.28,  val loss 0.539822, percent error 16.30
# Epoch    10, train loss 0.231917, train error 7.55,  val loss 0.364285, percent error 12.30
# Epoch    11, train loss 0.181509, train error 6.20,  val loss 0.338075, percent error 10.60
# Epoch    12, train loss 0.181143, train error 6.32,  val loss 0.319888, percent error 11.10
# Epoch    13, train loss 0.134866, train error 4.05,  val loss 0.307926, percent error 9.80
# Epoch    14, train loss 0.141963, train error 5.18,  val loss 0.318689, percent error 9.80
# Epoch    15, train loss 0.147260, train error 5.32,  val loss 0.364443, percent error 10.90
# Epoch    16, train loss 0.142500, train error 5.43,  val loss 0.342468, percent error 10.00
# Epoch    17, train loss 0.135015, train error 4.47,  val loss 0.335335, percent error 9.80
# Epoch    18, train loss 0.122873, train error 4.72,  val loss 0.325908, percent error 9.90
# Epoch    19, train loss 0.108835, train error 3.82,  val loss 0.305689, percent error 9.30
# Epoch    20, train loss 0.127499, train error 4.53,  val loss 0.322472, percent error 9.90
# Epoch    21, train loss 0.116685, train error 4.10,  val loss 0.333971, percent error 10.20
# Epoch    22, train loss 0.099394, train error 3.62,  val loss 0.316088, percent error 10.20
# Epoch    23, train loss 0.103096, train error 3.60,  val loss 0.346415, percent error 9.70
# Epoch    24, train loss 0.088687, train error 3.28,  val loss 0.309216, percent error 9.40
# Epoch    25, train loss 0.068617, train error 2.28,  val loss 0.331938, percent error 10.10
# Epoch    26, train loss 0.075772, train error 2.47,  val loss 0.306687, percent error 8.80
# Epoch    27, train loss 0.072728, train error 2.53,  val loss 0.332556, percent error 9.50
# Epoch    28, train loss 0.084706, train error 2.82,  val loss 0.381536, percent error 10.70
# Epoch    29, train loss 0.063638, train error 2.53,  val loss 0.346691, percent error 10.00
# Epoch    30, train loss 0.069268, train error 2.50,  val loss 0.339576, percent error 9.50
# Epoch    31, train loss 0.097304, train error 3.43,  val loss 0.411072, percent error 10.50
# Epoch    32, train loss 0.061967, train error 2.07,  val loss 0.340122, percent error 9.60
# Epoch    33, train loss 0.136308, train error 4.62,  val loss 0.435218, percent error 9.90
# Epoch    34, train loss 0.054635, train error 1.80,  val loss 0.351579, percent error 9.30
# Epoch    35, train loss 0.060893, train error 2.25,  val loss 0.337929, percent error 9.80
# Epoch    36, train loss 0.079690, train error 2.78,  val loss 0.358201, percent error 9.80
# Epoch    37, train loss 0.050906, train error 1.53,  val loss 0.343062, percent error 9.60
# Epoch    38, train loss 0.062622, train error 1.95,  val loss 0.366477, percent error 10.40
# Epoch    39, train loss 0.093694, train error 3.32,  val loss 0.382674, percent error 9.30
# Epoch    40, train loss 0.046408, train error 1.38,  val loss 0.359972, percent error 9.30
# Epoch    41, train loss 0.035690, train error 1.03,  val loss 0.344055, percent error 8.80
# Epoch    42, train loss 0.039779, train error 1.20,  val loss 0.364793, percent error 9.10
# Epoch    43, train loss 0.034522, train error 0.93,  val loss 0.377158, percent error 8.90
# Epoch    44, train loss 0.036998, train error 1.07,  val loss 0.392709, percent error 9.70
# Epoch    45, train loss 0.052685, train error 1.90,  val loss 0.424249, percent error 10.50
# Epoch    46, train loss 0.038985, train error 1.10,  val loss 0.396331, percent error 9.50
# Epoch    47, train loss 0.039036, train error 1.15,  val loss 0.418499, percent error 9.20
# Epoch    48, train loss 0.032554, train error 0.80,  val loss 0.411548, percent error 9.60
# Epoch    49, train loss 0.027481, train error 0.85,  val loss 0.406531, percent error 10.00
# Epoch    50, train loss 0.021187, train error 0.43,  val loss 0.391091, percent error 8.70
# Epoch    51, train loss 0.020331, train error 0.38,  val loss 0.408577, percent error 9.50
# Epoch    52, train loss 0.020957, train error 0.53,  val loss 0.399191, percent error 8.50
# Epoch    53, train loss 0.016716, train error 0.28,  val loss 0.395367, percent error 8.70
# Epoch    54, train loss 0.014491, train error 0.15,  val loss 0.401121, percent error 8.70
# Epoch    55, train loss 0.012726, train error 0.12,  val loss 0.405503, percent error 8.40
# Epoch    56, train loss 0.012010, train error 0.07,  val loss 0.434299, percent error 8.40
# Epoch    57, train loss 0.013308, train error 0.20,  val loss 0.428149, percent error 8.90
# Epoch    58, train loss 0.013370, train error 0.12,  val loss 0.428366, percent error 8.60
# Epoch    59, train loss 0.012210, train error 0.12,  val loss 0.412117, percent error 9.10
# Epoch    60, train loss 0.010866, train error 0.07,  val loss 0.439589, percent error 9.10
# Epoch    61, train loss 0.009755, train error 0.05,  val loss 0.439836, percent error 9.10
# Epoch    62, train loss 0.009781, train error 0.12,  val loss 0.438133, percent error 8.60
# Epoch    63, train loss 0.007770, train error 0.00,  val loss 0.444442, percent error 8.60
# Epoch    64, train loss 0.007801, train error 0.00,  val loss 0.453996, percent error 9.20
# Epoch    65, train loss 0.007299, train error 0.00,  val loss 0.452728, percent error 9.00
# Epoch    66, train loss 0.006929, train error 0.00,  val loss 0.455947, percent error 9.20
# Epoch    67, train loss 0.006733, train error 0.00,  val loss 0.466535, percent error 8.90
# Epoch    68, train loss 0.006229, train error 0.00,  val loss 0.456928, percent error 8.80
# Epoch    69, train loss 0.005912, train error 0.00,  val loss 0.466925, percent error 9.10
# Epoch    70, train loss 0.005661, train error 0.00,  val loss 0.466860, percent error 8.60
# Epoch    71, train loss 0.005431, train error 0.00,  val loss 0.473021, percent error 9.00
# Epoch    72, train loss 0.005398, train error 0.00,  val loss 0.472758, percent error 9.00
# Epoch    73, train loss 0.005359, train error 0.00,  val loss 0.476758, percent error 8.90
# Epoch    74, train loss 0.005302, train error 0.00,  val loss 0.484160, percent error 9.20
# Epoch    75, train loss 0.005092, train error 0.00,  val loss 0.477557, percent error 8.50
# Epoch    76, train loss 0.005029, train error 0.00,  val loss 0.485985, percent error 8.80
# Epoch    77, train loss 0.004802, train error 0.00,  val loss 0.488329, percent error 8.80
# Epoch    78, train loss 0.004675, train error 0.00,  val loss 0.483727, percent error 8.60
# Epoch    79, train loss 0.004603, train error 0.00,  val loss 0.491879, percent error 8.90
# Epoch    80, train loss 0.004279, train error 0.00,  val loss 0.491387, percent error 9.00
# Epoch    81, train loss 0.004269, train error 0.00,  val loss 0.495347, percent error 9.30
# Epoch    82, train loss 0.004382, train error 0.00,  val loss 0.501351, percent error 9.10
# Epoch    83, train loss 0.004111, train error 0.00,  val loss 0.501212, percent error 9.30
# Epoch    84, train loss 0.004119, train error 0.00,  val loss 0.500809, percent error 8.70
# Epoch    85, train loss 0.004099, train error 0.00,  val loss 0.504370, percent error 9.10
# Epoch    86, train loss 0.003799, train error 0.00,  val loss 0.505785, percent error 9.10
# Epoch    87, train loss 0.003735, train error 0.00,  val loss 0.506429, percent error 9.30
# Epoch    88, train loss 0.003688, train error 0.00,  val loss 0.509263, percent error 9.30
# Epoch    89, train loss 0.003617, train error 0.00,  val loss 0.509202, percent error 9.10
# Epoch    90, train loss 0.003626, train error 0.00,  val loss 0.509901, percent error 9.10
# Epoch    91, train loss 0.003507, train error 0.00,  val loss 0.514484, percent error 9.10
# Epoch    92, train loss 0.003464, train error 0.00,  val loss 0.512351, percent error 9.20
# Epoch    93, train loss 0.003448, train error 0.00,  val loss 0.517656, percent error 9.20
# Epoch    94, train loss 0.003331, train error 0.00,  val loss 0.518624, percent error 9.10
# Epoch    95, train loss 0.003267, train error 0.00,  val loss 0.521206, percent error 9.30
# Epoch    96, train loss 0.003250, train error 0.00,  val loss 0.520890, percent error 9.30
# Epoch    97, train loss 0.003329, train error 0.00,  val loss 0.526137, percent error 9.40
# Epoch    98, train loss 0.003152, train error 0.00,  val loss 0.524006, percent error 9.00
# Epoch    99, train loss 0.003113, train error 0.00,  val loss 0.524036, percent error 9.30
